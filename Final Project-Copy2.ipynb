# %%
import turtle 
import time 

scr=turtle.getscreen()
scr.title("American Flag2")
scr.bgcolor("#FFFFFF")

t=turtle.Turtle()
t.speed(100)
t.penup()

## stripes
def draw_rectangle(height,width,color):
    t.goto(x,y)
    t.pendown()
    t.color(color)
    t.begin_fill()
    
    t.forward(width)
    t.right(90)
    t.forward(height)
    t.right(90)
    t.forward(width)
    t.right(90)
    t.forward(height)
    t.right(90)
    
    t.end_fill()
    t.penup()

def draw_stripes():
    color = "#B22234"
    height = 500
    width = height*1.9
    str_height = height/13
    str_width = width
    x = -475
    y = 250
    
    t.color(color)
    t.begin_fill()
    for stripe in range(8):
        draw_rectangle(str_height, str_width, "#B22234")
        y = y-str_height
    draw_rectangle(str_height, str_width, "#FFFFFF")
    y = y-str_height
       
    
        #t.forward(str_width)
        #t.right(90)
        #t.forward(str_height)
        #t.right(90)
    t.end_fill()  
## repeating stripes
#for i in range(7):
  #  x = -475
   # y = 250

    #t.penup()
   # t.goto(x, y)
   # t.pendown()
   # draw_stripes()
   # y = y - 76
    
## canton
def draw_canton():
    color = "#3C3B6E"
    height = 200
    width = height*1.9
    c_width = width * (2/5)
    c_height = height * (7/13)
    
    t.penup()
    t.goto(-152, 108)
    t.pendown()
    t.color(color)
    t.begin_fill()

    for i in range(2):
        t.forward(c_width)
        t.right(90)
        t.forward(c_height)
        t.right(90)
    t.end_fill()
    
## stars
def draw_stars():
    size = 8
    color = "#FFFFFF"
    
    t.color(color)
    t.begin_fill()
    
    for i in range(5):
        t.forward(size)
        t.right(144)
    t.end_fill()
    
def six_stars():
    x1 = - 145
    y1 = 95
    # loop for drawing multiple rows of stars
    for row in range(5):
        for star in range(6):
            t.penup()
            t.goto(x1, y1)
            t.pendown()
            draw_stars()
            x1 = x1 + 25
        # reset x1 to the starting position
        x1 = - 145
        # move down to the next row
        # modify this as you wish to set the distance between rows.
        y1 = y1 - 20
def five_stars():
    x2 = - 132
    y2 = 85
    # loop for drawing multiple rows of stars
    for row in range(4):
        for star in range(5):
            t.penup()
            t.goto(x2, y2)
            t.pendown()
            draw_stars()
            x2 = x2 + 25
        # reset x1 to the starting position
        x2 = - 132
        # move down to the next row
        # modify this as you wish to set the distance between rows.
        y2 = y2 - 20

#draw_stripes()
draw_canton()
six_stars()
five_stars()
t.hideturtle
# Out:
# <bound method TPen.hideturtle of <turtle.Turtle object at 0x7f9721e2a430>>
